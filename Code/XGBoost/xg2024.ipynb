# %%
import pandas as pd
import numpy as np
import xgboost as xgb

df = pd.read_csv(r"D:\NATPAC\Datasets\XGBoost\2023.csv")
df.drop(df.columns[0], axis=1, inplace=True)

X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

model_xgb = xgb.XGBRegressor()
model_xgb.fit(X, y)

forecast_2024 = model_xgb.predict(X)

print(forecast_2024)
# Out:
# [1294911.5    820957.6   1190855.9   2047082.9   1159772.4   1194500.6
#  1192900.1    332899.84   774521.    2619861.8   1593974.2   1471914.4
#  1188323.1   1229293.4    442666.75  1462263.2    286866.28   235090.6
#  1144671.2   1202742.1   2085516.4    997559.1   1131349.1    186138.69
#  1170521.    1164998.6    205487.55  1205870.4    180729.08  1635605.9
#  1172802.9   1449331.8   1739330.1   1257554.2   1176705.9    600053.25
#  1198989.    1754334.6    230803.11  2383934.     482495.97  1337487.5
#   825718.75   167160.23  1250575.1   1546684.5   1966942.9    995751.5
#  1180423.4   1215051.5    767543.44   281741.12  2042182.9    867943.75
#  1129997.1   3450563.5    149325.28  1930978.5   1199464.2   1230600.5
#   435407.84  1191921.8   2469811.2   1175840.8   1189644.4   1254265.4
#  1678399.4   2151749.2    441852.56  2598318.2   1760120.8    103017.18
#   134533.23  1151631.5   1251987.1   1131707.9   4012165.5   1189787.9
# ...

# %%
import matplotlib.pyplot as plt
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
month_ticks = np.arange(0, 366, 30.5)
days = range(366)
plt.figure(figsize=(15, 8))
plt.plot(days, forecast_2024, marker='')
plt.xlabel('Months')
plt.ylabel('Quantity')
plt.title('Predicted Data for 2024')
plt.xticks(month_ticks, months)
plt.xlim(0, 366)
plt.show()

# %%
import pandas as pd

df2 = pd.read_csv(r"D:\NATPAC\Datasets\XGBoost\2023.csv")

new_df = pd.DataFrame(forecast_2024, columns=["2024"])

result_df = pd.concat([df2, new_df], axis=1)

result_df.to_csv(r"D:\NATPAC\Datasets\XGBoost\2024.csv", index=False)

print(result_df)
# Out:
#     Month_Day     2018     2019     2020     2021     2022        2023  \
# 0       01-01   337485   686993  1284272  1244317  1285112  1298694.90
# 1       01-02  1030556  1920106   985410  1499299   805926   819765.75
# 2       01-03  1030556  1598395   985410  1115398  1198180  1186258.60
# 3       01-04   697207  1621244   110652   213313  2054215  2047270.50
# 4       01-05  1464201   148152   985410  1020265  1198180  1157794.40
# ..        ...      ...      ...      ...      ...      ...         ...
# 361     12-27   125924   643626   985410  2648166  1669346  1664739.80
# 362     12-28  2477337   995967  3430383  1001102  1113987  1114991.80
# 363     12-29  1030556   392141   985410   966369   278274   420851.70
# 364     12-30  1030556  1054901   134188   178873   416466   429874.62
# 365     12-31   903441  1088381   985410  1001102  1218553  1214974.60
#
#              2024
# 0    1.294912e+06
# 1    8.209576e+05
# 2    1.190856e+06
# 3    2.047083e+06
# ...
