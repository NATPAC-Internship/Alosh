# %%
import pandas as pd
import numpy as np
from catboost import CatBoostRegressor

df = pd.read_csv(r"D:\NATPAC-Alosh\Datasets\CatBoost\2024.csv")
df.drop(df.columns[0], axis=1, inplace=True)

X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

model_cat = CatBoostRegressor(n_estimators=50000)
model_cat.fit(X, y)

forecast_2025_cat = model_cat.predict(X)

print(forecast_2025_cat)
# Out:
# Learning rate set to 0.001452
# 0:	learn: 675851.1165142	total: 141ms	remaining: 1h 57m 9s
# 1:	learn: 675181.3752651	total: 143ms	remaining: 59m 25s
# 2:	learn: 674546.3726937	total: 144ms	remaining: 40m 3s
# 3:	learn: 673851.0929802	total: 146ms	remaining: 30m 29s
# 4:	learn: 673161.6007862	total: 148ms	remaining: 24m 39s
# 5:	learn: 672384.3069064	total: 150ms	remaining: 20m 45s
# 6:	learn: 671714.0391636	total: 151ms	remaining: 18m 1s
# 7:	learn: 671053.6533085	total: 153ms	remaining: 15m 58s
# 8:	learn: 670325.8115759	total: 155ms	remaining: 14m 23s
# 9:	learn: 669655.6473381	total: 158ms	remaining: 13m 8s
# 10:	learn: 668962.4421420	total: 159ms	remaining: 12m 3s
# 11:	learn: 668382.7886747	total: 161ms	remaining: 11m 8s
# 12:	learn: 667745.6963781	total: 162ms	remaining: 10m 23s
# 13:	learn: 667154.8925800	total: 164ms	remaining: 9m 45s
# 14:	learn: 666427.1873956	total: 165ms	remaining: 9m 10s
# 15:	learn: 665671.8245406	total: 167ms	remaining: 8m 41s
# ...

# %%
import matplotlib.pyplot as plt
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
month_ticks = np.arange(0, 366, 30.5)
days = range(366)
plt.figure(figsize=(15, 8))
plt.plot(days, forecast_2025_cat, marker='')
plt.xlabel('Months')
plt.ylabel('Quantity')
plt.title('Predicted Data for 2025')
plt.xticks(month_ticks, months)
plt.xlim(0, 366)
plt.show()

# %%
import pandas as pd

df2 = pd.read_csv(r"D:\NATPAC-Alosh\Datasets\CatBoost\2024.csv")

new_df = pd.DataFrame(forecast_2025_cat, columns=["2025"])

result_df = pd.concat([df2, new_df], axis=1)

result_df.to_csv(r"D:\NATPAC-Alosh\Datasets\CatBoost\2025.csv", index=False)

print(result_df)
# Out:
#     Month_Day     2018     2019     2020     2021     2022          2023  \
# 0       01-01   337485   686993  1284272  1244317  1285112  1.386942e+06
# 1       01-02  1030556  1920106   985410  1499299   805926  8.703654e+05
# 2       01-03  1030556  1598395   985410  1115398  1198180  1.267312e+06
# 3       01-04   697207  1621244   110652   213313  2054215  1.853981e+06
# 4       01-05  1464201   148152   985410  1020265  1198180  1.249788e+06
# ..        ...      ...      ...      ...      ...      ...           ...
# 361     12-27   125924   643626   985410  2648166  1669346  1.611026e+06
# 362     12-28  2477337   995967  3430383  1001102  1113987  1.048108e+06
# 363     12-29  1030556   392141   985410   966369   278274  7.662052e+05
# 364     12-30  1030556  1054901   134188   178873   416466  5.298365e+05
# 365     12-31   903441  1088381   985410  1001102  1218553  1.259296e+06
#
#              2024          2025
# 0    1.358868e+06  1.358311e+06
# ...
