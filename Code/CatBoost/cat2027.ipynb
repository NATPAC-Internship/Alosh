# %%
import pandas as pd
import numpy as np
from catboost import CatBoostRegressor

df = pd.read_csv(r"D:\NATPAC-Alosh\Datasets\CatBoost\2026.csv")
df.drop(df.columns[0], axis=1, inplace=True)

X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

model_cat = CatBoostRegressor(n_estimators=50000)
model_cat.fit(X, y)

forecast_2027_cat = model_cat.predict(X)

print(forecast_2027_cat)
# Out:
# Learning rate set to 0.001452
# 0:	learn: 675624.9687580	total: 140ms	remaining: 1h 56m 55s
# 1:	learn: 674900.6006972	total: 142ms	remaining: 59m 17s
# 2:	learn: 674182.9705561	total: 144ms	remaining: 40m 7s
# 3:	learn: 673566.4327876	total: 146ms	remaining: 30m 26s
# 4:	learn: 672799.0634901	total: 148ms	remaining: 24m 37s
# 5:	learn: 672061.7370104	total: 149ms	remaining: 20m 43s
# 6:	learn: 671265.2183783	total: 151ms	remaining: 17m 58s
# 7:	learn: 670542.1319798	total: 153ms	remaining: 15m 56s
# 8:	learn: 669743.6237503	total: 154ms	remaining: 14m 18s
# 9:	learn: 669044.2347243	total: 156ms	remaining: 13m
# 10:	learn: 668367.5918934	total: 158ms	remaining: 11m 57s
# 11:	learn: 667654.6379630	total: 160ms	remaining: 11m 5s
# 12:	learn: 666916.7361238	total: 161ms	remaining: 10m 19s
# 13:	learn: 666280.1507330	total: 162ms	remaining: 9m 40s
# 14:	learn: 665570.5922889	total: 164ms	remaining: 9m 6s
# 15:	learn: 664797.0514214	total: 166ms	remaining: 8m 37s
# ...

# %%
import matplotlib.pyplot as plt
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
month_ticks = np.arange(0, 366, 30.5)
days = range(366)
plt.figure(figsize=(15, 8))
plt.plot(days, forecast_2027_cat, marker='')
plt.xlabel('Months')
plt.ylabel('Quantity')
plt.title('Predicted Data for 2027')
plt.xticks(month_ticks, months)
plt.xlim(0, 366)
plt.show()

# %%
import pandas as pd

df2 = pd.read_csv(r"D:\NATPAC-Alosh\Datasets\CatBoost\2026.csv")

new_df = pd.DataFrame(forecast_2027_cat, columns=["2027"])

result_df = pd.concat([df2, new_df], axis=1)

result_df.to_csv(r"D:\NATPAC-Alosh\Datasets\CatBoost\2027.csv", index=False)

print(result_df)
# Out:
#     Month_Day     2018     2019     2020     2021     2022          2023  \
# 0       01-01   337485   686993  1284272  1244317  1285112  1.386942e+06
# 1       01-02  1030556  1920106   985410  1499299   805926  8.703654e+05
# 2       01-03  1030556  1598395   985410  1115398  1198180  1.267312e+06
# 3       01-04   697207  1621244   110652   213313  2054215  1.853981e+06
# 4       01-05  1464201   148152   985410  1020265  1198180  1.249788e+06
# ..        ...      ...      ...      ...      ...      ...           ...
# 361     12-27   125924   643626   985410  2648166  1669346  1.611026e+06
# 362     12-28  2477337   995967  3430383  1001102  1113987  1.048108e+06
# 363     12-29  1030556   392141   985410   966369   278274  7.662052e+05
# 364     12-30  1030556  1054901   134188   178873   416466  5.298365e+05
# 365     12-31   903441  1088381   985410  1001102  1218553  1.259296e+06
#
#              2024          2025          2026          2027
# ...
