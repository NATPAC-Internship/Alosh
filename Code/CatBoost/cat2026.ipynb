# %%
import pandas as pd
import numpy as np
from catboost import CatBoostRegressor

df = pd.read_csv(r"D:\NATPAC-Alosh\Datasets\CatBoost\2025.csv")
df.drop(df.columns[0], axis=1, inplace=True)

X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

model_cat = CatBoostRegressor(n_estimators=50000)
model_cat.fit(X, y)

forecast_2026_cat = model_cat.predict(X)

print(forecast_2026_cat)
# Out:
# Learning rate set to 0.001452
# 0:	learn: 675569.3891096	total: 137ms	remaining: 1h 54m 26s
# 1:	learn: 674949.1554127	total: 139ms	remaining: 58m 6s
# 2:	learn: 674298.8834756	total: 141ms	remaining: 39m 8s
# 3:	learn: 673560.4572488	total: 143ms	remaining: 29m 44s
# 4:	learn: 672802.3511632	total: 145ms	remaining: 24m 4s
# 5:	learn: 672120.9850202	total: 146ms	remaining: 20m 16s
# 6:	learn: 671361.3818457	total: 148ms	remaining: 17m 33s
# 7:	learn: 670622.4294345	total: 149ms	remaining: 15m 34s
# 8:	learn: 669895.3063686	total: 151ms	remaining: 13m 58s
# 9:	learn: 669160.9130083	total: 152ms	remaining: 12m 42s
# 10:	learn: 668462.6713331	total: 154ms	remaining: 11m 40s
# 11:	learn: 667760.1186588	total: 156ms	remaining: 10m 49s
# 12:	learn: 666988.4647987	total: 157ms	remaining: 10m 5s
# 13:	learn: 666326.5853930	total: 159ms	remaining: 9m 29s
# 14:	learn: 665628.5831973	total: 161ms	remaining: 8m 55s
# 15:	learn: 664967.1466245	total: 162ms	remaining: 8m 26s
# ...

# %%
import matplotlib.pyplot as plt
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
month_ticks = np.arange(0, 366, 30.5)
days = range(366)
plt.figure(figsize=(15, 8))
plt.plot(days, forecast_2026_cat, marker='')
plt.xlabel('Months')
plt.ylabel('Quantity')
plt.title('Predicted Data for 2026')
plt.xticks(month_ticks, months)
plt.xlim(0, 366)
plt.show()

# %%
import pandas as pd

df2 = pd.read_csv(r"D:\NATPAC-Alosh\Datasets\CatBoost\2025.csv")

new_df = pd.DataFrame(forecast_2026_cat, columns=["2026"])

result_df = pd.concat([df2, new_df], axis=1)

result_df.to_csv(r"D:\NATPAC-Alosh\Datasets\CatBoost\2026.csv", index=False)

print(result_df)
# Out:
#     Month_Day     2018     2019     2020     2021     2022          2023  \
# 0       01-01   337485   686993  1284272  1244317  1285112  1.386942e+06
# 1       01-02  1030556  1920106   985410  1499299   805926  8.703654e+05
# 2       01-03  1030556  1598395   985410  1115398  1198180  1.267312e+06
# 3       01-04   697207  1621244   110652   213313  2054215  1.853981e+06
# 4       01-05  1464201   148152   985410  1020265  1198180  1.249788e+06
# ..        ...      ...      ...      ...      ...      ...           ...
# 361     12-27   125924   643626   985410  2648166  1669346  1.611026e+06
# 362     12-28  2477337   995967  3430383  1001102  1113987  1.048108e+06
# 363     12-29  1030556   392141   985410   966369   278274  7.662052e+05
# 364     12-30  1030556  1054901   134188   178873   416466  5.298365e+05
# 365     12-31   903441  1088381   985410  1001102  1218553  1.259296e+06
#
#              2024          2025          2026
# ...
