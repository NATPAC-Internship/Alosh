# %%
import pandas as pd
import numpy as np
from catboost import CatBoostRegressor

df = pd.read_csv(r"D:\NATPAC\Datasets\CatBoost\2023.csv")
df.drop(df.columns[0], axis=1, inplace=True)

X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

model_cat = CatBoostRegressor(n_estimators=50000)
model_cat.fit(X, y)

forecast_2024_cat = model_cat.predict(X)

print(forecast_2024_cat)
# Out:
# Learning rate set to 0.001452
# 0:	learn: 677623.6275601	total: 2.63ms	remaining: 2m 11s
# 1:	learn: 676977.2561984	total: 4.83ms	remaining: 2m
# 2:	learn: 676331.3349971	total: 7.66ms	remaining: 2m 7s
# 3:	learn: 675781.6439560	total: 9.63ms	remaining: 2m
# 4:	learn: 675227.4540948	total: 11.5ms	remaining: 1m 54s
# 5:	learn: 674542.8230302	total: 13ms	remaining: 1m 47s
# 6:	learn: 673878.5883869	total: 14.9ms	remaining: 1m 46s
# 7:	learn: 673183.8217327	total: 17.6ms	remaining: 1m 50s
# 8:	learn: 672545.1822821	total: 19.7ms	remaining: 1m 49s
# 9:	learn: 671908.1298800	total: 21.3ms	remaining: 1m 46s
# 10:	learn: 671213.6636280	total: 23.1ms	remaining: 1m 44s
# 11:	learn: 670610.1576841	total: 24.7ms	remaining: 1m 43s
# 12:	learn: 669938.1143477	total: 26.6ms	remaining: 1m 42s
# 13:	learn: 669416.0588401	total: 28.4ms	remaining: 1m 41s
# 14:	learn: 668810.4671766	total: 30.2ms	remaining: 1m 40s
# 15:	learn: 668077.2749805	total: 32ms	remaining: 1m 39s
# ...

# %%
import matplotlib.pyplot as plt
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
month_ticks = np.arange(0, 366, 30.5)
days = range(366)
plt.figure(figsize=(15, 8))
plt.plot(days, forecast_2024_cat, marker='')
plt.xlabel('Months')
plt.ylabel('Quantity')
plt.title('Predicted Data for 2024')
plt.xticks(month_ticks, months)
plt.xlim(0, 366)
plt.show()

# %%
import pandas as pd

df2 = pd.read_csv(r"D:\NATPAC\Datasets\CatBoost\2023.csv")

new_df = pd.DataFrame(forecast_2024_cat, columns=["2024"])

result_df = pd.concat([df2, new_df], axis=1)

result_df.to_csv(r"D:\NATPAC\Datasets\CatBoost\2024.csv", index=False)

print(result_df)
# Out:
#     Month_Day     2018     2019     2020     2021     2022          2023  \
# 0       01-01   337485   686993  1284272  1244317  1285112  1.386942e+06
# 1       01-02  1030556  1920106   985410  1499299   805926  8.703654e+05
# 2       01-03  1030556  1598395   985410  1115398  1198180  1.267312e+06
# 3       01-04   697207  1621244   110652   213313  2054215  1.853981e+06
# 4       01-05  1464201   148152   985410  1020265  1198180  1.249788e+06
# ..        ...      ...      ...      ...      ...      ...           ...
# 361     12-27   125924   643626   985410  2648166  1669346  1.611026e+06
# 362     12-28  2477337   995967  3430383  1001102  1113987  1.048108e+06
# 363     12-29  1030556   392141   985410   966369   278274  7.662052e+05
# 364     12-30  1030556  1054901   134188   178873   416466  5.298365e+05
# 365     12-31   903441  1088381   985410  1001102  1218553  1.259296e+06
#
#              2024
# 0    1.358868e+06
# 1    8.728569e+05
# 2    1.245057e+06
# ...
