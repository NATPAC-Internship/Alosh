# %%
import pandas as pd
import numpy as np
from ngboost import NGBRegressor

df = pd.read_csv(r"D:\NATPAC\Datasets\NGBoost\2023.csv")
df.drop(df.columns[0], axis=1, inplace=True)

X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

model_ngb = NGBRegressor(n_estimators=2000)
model_ngb.fit(X, y)

forecast_2024_ngb = model_ngb.predict(X)

print(forecast_2024_ngb)
# Out:
# [iter 0] loss=14.4590 val_loss=0.0000 scale=1.0000 norm=310308.1310
# [iter 100] loss=13.5312 val_loss=0.0000 scale=2.0000 norm=271130.5928
# [iter 200] loss=13.1959 val_loss=0.0000 scale=2.0000 norm=220400.5326
# [iter 300] loss=13.0636 val_loss=0.0000 scale=1.0000 norm=101379.5336
# [iter 400] loss=12.9799 val_loss=0.0000 scale=1.0000 norm=95224.1092
# [iter 500] loss=12.9003 val_loss=0.0000 scale=1.0000 norm=89467.6212
# [iter 600] loss=12.8259 val_loss=0.0000 scale=1.0000 norm=84430.8460
# [iter 700] loss=12.7566 val_loss=0.0000 scale=1.0000 norm=79946.0365
# [iter 800] loss=12.6831 val_loss=0.0000 scale=1.0000 norm=75643.9578
# [iter 900] loss=12.6156 val_loss=0.0000 scale=1.0000 norm=71994.6912
# [iter 1000] loss=12.5629 val_loss=0.0000 scale=1.0000 norm=69174.0307
# [iter 1100] loss=12.5134 val_loss=0.0000 scale=1.0000 norm=66712.7231
# [iter 1200] loss=12.4733 val_loss=0.0000 scale=1.0000 norm=64595.8467
# [iter 1300] loss=12.4387 val_loss=0.0000 scale=0.5000 norm=31413.5097
# ...

# %%
import matplotlib.pyplot as plt
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
month_ticks = np.arange(0, 366, 30.5)
days = range(366)
plt.figure(figsize=(15, 8))
plt.plot(days, forecast_2024_ngb, marker='')
plt.xlabel('Months')
plt.ylabel('Quantity')
plt.title('Predicted Data for 2024')
plt.xticks(month_ticks, months)
plt.xlim(0, 366)
plt.show()

# %%
import pandas as pd

df2 = pd.read_csv(r"D:\NATPAC\Datasets\NGBoost\2023.csv")

new_df = pd.DataFrame(forecast_2024_ngb, columns=["2024"])

result_df = pd.concat([df2, new_df], axis=1)

result_df.to_csv(r"D:\NATPAC\Datasets\NGBoost\2024.csv", index=False)

print(result_df)
# Out:
#     Month_Day     2018     2019     2020     2021     2022          2023  \
# 0       01-01   337485   686993  1284272  1244317  1285112  1.425739e+06
# 1       01-02  1030556  1920106   985410  1499299   805926  9.357349e+05
# 2       01-03  1030556  1598395   985410  1115398  1198180  1.191723e+06
# 3       01-04   697207  1621244   110652   213313  2054215  1.459777e+06
# 4       01-05  1464201   148152   985410  1020265  1198180  1.248669e+06
# ..        ...      ...      ...      ...      ...      ...           ...
# 361     12-27   125924   643626   985410  2648166  1669346  1.451603e+06
# 362     12-28  2477337   995967  3430383  1001102  1113987  9.859712e+05
# 363     12-29  1030556   392141   985410   966369   278274  1.123267e+06
# 364     12-30  1030556  1054901   134188   178873   416466  8.302768e+05
# 365     12-31   903441  1088381   985410  1001102  1218553  1.246643e+06
#
#              2024
# 0    1.388649e+06
# 1    1.001311e+06
# 2    1.208878e+06
# ...
